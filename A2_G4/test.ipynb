# %%
# pandas and numpy for reading and manipulating the data

import pandas as pd
import numpy as np

# matplotlib and seaborn for visualizing the data

import matplotlib.pyplot as plt 
import seaborn as sns

# Counter for counting the number of data points in each clusters

from collections import Counter

# Necessary modules for Standardising the data and using ML algorithms

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN, KMeans

# silhouette_score for evaluating the clusters, ranges from -1 to +1, desirable score is close to 1

from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('./artd-31.csv', header=None)
df.columns = ['id', 'x', 'y', 'cluster']
df.head()
# Out:
#    id        x       y  cluster
# 0  p1  25.0514  5.7475        1
# 1  p2  26.6614  7.3414        1
# 2  p3  25.2653  6.2466        1
# 3  p4  25.2285  4.7447        1
# 4  p5  25.7529  5.1564        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       5000 non-null   object
#  1   x        5000 non-null   float64
#  2   y        5000 non-null   float64
#  3   cluster  5000 non-null   int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 156.4+ KB

# %%
sns.scatterplot(x='x', y='y', hue='cluster', data=df, palette='tab10')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
made = pd.read_csv('./output.csv')
sns.scatterplot(x='x', y='y', hue='cluster_id',     data=made, palette='tab10')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
made = pd.read_csv('./output.csv')
sns.scatterplot(x='x', y='y', hue='cluster_id',     data=made, palette='tab10')
# Out:
# <Axes: xlabel='x', ylabel='y'>
